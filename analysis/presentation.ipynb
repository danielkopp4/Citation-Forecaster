# %%
# import networkx as nx
# import matplotlib.pyplot as plt

# # Example data: Nodes represent publications, Edges represent "cited by" relationships
# citations = [
#     (" A", " B"),
#     (" A", " C"),
#     (" B", " C"),
#     (" C", " D"),
#     (" D", " E"),
#     (" E", " A")  # Example of a circular citation
# ]

# # Create a directed graph
# G = nx.DiGraph()

# # Add nodes and edges to the graph
# G.add_edges_from(citations)

# # Graph layout for better visualization
# pos = nx.spring_layout(G, seed=42)  # You can try different layouts like circular_layout, shell_layout

# # Draw the graph with customizations
# plt.figure(figsize=(10, 8))

# # Nodes
# nx.draw_networkx_nodes(G, pos, node_size=2000, node_color='lightblue', alpha=0.9)

# Edges
# nx.draw_networkx_edges(G, pos, edge_color='gray', arrowstyle='->', arrowsize=20)

# Labels
# nx.draw_networkx_labels(G, pos, font_size=12, font_family='sans-serif')

# # Title and other customizations
# plt.title("Citation Graph Example", size=15)
# plt.axis('off')  # Turn off the axis
# plt.show()

# %%
import networkx as nx
import matplotlib.pyplot as plt
import numpy as np

# Example data: Nodes represent publications, Edges represent "cited by" relationships
# Format: (citing publication, cited publication)
citations = [
    # ("A", "B"),
    # ("A", "C"),
    # ("B", "C"),
    # ("C", "D"),
    # ("D", "E"),
    (" ", " ") 
]

# Create a directed graph
G = nx.DiGraph()

# Add nodes and edges to the graph
G.add_edges_from(citations)

# print(G)
# y_pos = 9
# y_dec = 10
# try:
#     topo_order = list(nx.topological_sort(G))
#     # Assign each node a position in 2D space
#     pos = {node: (i, y_pos + 10*i - (i**2)*y_dec) for i, node in enumerate(topo_order)}

#     # Draw the graph with customizations
    # plt.figure(figsize=(10, 4))
    # nx.draw(G, pos, with_labels=True, node_color='lightblue', node_size=2000, 
    #         edge_color='gray', arrowstyle='->', arrowsize=20, font_size=12)
#     # plt.title("Topologically Sorted Citation Graph")
#     plt.show()
# except nx.NetworkXUnfeasible:
#     print("Graph has a cycle and cannot be topologically sorted.")
plt.figure(figsize=(10, 10))

nx.draw(G, {" ": (0, 10)}, with_labels=True, node_color='lightblue', node_size=2000, 
            edge_color='gray', arrowstyle='->', arrowsize=0, font_size=12)
plt.show()
